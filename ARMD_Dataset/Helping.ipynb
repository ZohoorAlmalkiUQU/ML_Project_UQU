# %%
# Out:
# features = {'Q25_diasbp', 'medication_name', 'last_cr', 'comorbidity_component', 'time_to_culturetime', 'Q25_bun', 'last_na', 'last_diasbp', 'median_heartrate', 'last_procalcitonin', 'susceptibility', 'medication_category', 'procedure_time_to_culturetime', 'antibiotic_class', 'order_proc_id_coded', 'culture_description', 'Q25_wbc', 'antibiotic_subtype_category', 'hosp_ward_IP', 'last_heartrate', 'Q75_plt', 'first_neutrophils', 'Q25_hgb', 'last_temp', 'first_sysbp', 'Q75_hgb', 'Q75_neutrophils', 'Q75_diasbp', 'Rule', 'median_na', 'first_bun', 'median_sysbp', 'median_resprate', 'nursing_home_visit_culture', 'organism', 'prior_organism', 'Q75_bun', 'medication_time_to_cultureTime', 'first_hco3', 'first_heartrate', 'medication_time_to_culturetime', 'median_diasbp', 'resistant_time_to_culturetime', 'hosp_ward_ER', 'median_bun', 'Q25_sysbp', 'anon_id', 'Q25_resprate', 'Q75_cr', 'last_wbc', 'first_temp', 'ordering_mode', 'comorbidity_component_end_days_culture', 'Q75_lymphocytes', 'Q75_na',
# ...
